# %%
# %run "/Shared/WeatherWatts/config/api keys"

# %%
import requests
import pandas as pd

# %%
locations =[ "CISO", "ERCO","NYIS","FLA"]

# %%
def json_to_dateframe(response):
    return pd.DataFrame(response.json()['response']['data'][1:], columns= response.json()['response']['data'][0])

# %%
from time import sleep
df_final = pd.DataFrame()
for loc in locations:
    for x in range(0,145_000,5000):
        try:
            url = f'https://api.eia.gov/v2/electricity/rto/region-data/data/?api_key={key}&frequency=hourly&data[0]=value&facets[type][]=D&facets[type][]=NG&facets[respondent][]={loc}&sort[0][column]=period&sort[0][direction]=asc&offset={x}&length=5000'
            response = requests.get(url)
            df = json_to_dateframe(response)
            df_final = pd.concat([df_final,df])
            print(response)
            if x%50000 == 0:
                sleep(45)
        except:
            print('error')
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# error
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# error
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# error
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# error

# %% [markdown]
# sparkDF=spark.createDataFrame(pandasDF)

# %%
df = spark.createDataFrame(df_final)

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>period</th><th>respondent</th><th>respondent-name</th><th>type</th><th>type-name</th><th>value</th><th>value-units</th></tr></thead><tbody><tr><td>2015-07-01T08</td><td>CISO</td><td>California Independent System Operator</td><td>NG</td><td>Net generation</td><td>25789.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T09</td><td>CISO</td><td>California Independent System Operator</td><td>D</td><td>Demand</td><td>28989.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T09</td><td>CISO</td><td>California Independent System Operator</td><td>NG</td><td>Net generation</td><td>23688.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T10</td><td>CISO</td><td>California Independent System Operator</td><td>D</td><td>Demand</td><td>27416.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T10</td><td>CISO</td><td>California Independent System Operator</td><td>NG</td><td>Net generation</td><td>22107.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T11</td><td>CISO</td><td>California Independent System Operator</td><td>D</td><td>Demand</td><td>26388.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T11</td><td>CISO</td><td>California Independent System Operator</td><td>NG</td><td>Net generation</td><td>20877.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T12</td><td>CISO</td><td>California Independent System Operator</td><td>D</td><td>Demand</td><td>25661.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T12</td><td>CISO</td><td>California Independent System Operator</td><td>NG</td><td>Net generation</td><td>20262.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T13</td><td>CISO</td><td>California Independent System Operator</td><td>D</td><td>Demand</td><td>25845.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T13</td><td>CISO</td><td>California Independent System Operator</td><td>NG</td><td>Net generation</td><td>20578.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T14</td><td>CISO</td><td>California Independent System Operator</td><td>D</td><td>Demand</td><td>26555.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T14</td><td>CISO</td><td>California Independent System Operator</td><td>NG</td><td>Net generation</td><td>20930.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T15</td><td>CISO</td><td>California Independent System Operator</td><td>D</td><td>Demand</td><td>28008.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T15</td><td>CISO</td><td>California Independent System Operator</td><td>NG</td><td>Net generation</td><td>23204.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T16</td><td>CISO</td><td>California Independent System Operator</td><td>D</td><td>Demand</td><td>29973.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T16</td><td>CISO</td><td>California Independent System Operator</td><td>NG</td><td>Net generation</td><td>25562.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T17</td><td>CISO</td><td>California Independent System Operator</td><td>D</td><td>Demand</td><td>31742.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T17</td><td>CISO</td><td>California Independent System Operator</td><td>NG</td><td>Net generation</td><td>27378.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T18</td><td>CISO</td><td>California Independent System Operator</td><td>D</td><td>Demand</td><td>33192.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T18</td><td>CISO</td><td>California Independent System Operator</td><td>NG</td><td>Net generation</td><td>29309.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T19</td><td>CISO</td><td>California Independent System Operator</td><td>D</td><td>Demand</td><td>34386.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T19</td><td>CISO</td><td>California Independent System Operator</td><td>NG</td><td>Net generation</td><td>30259.0</td><td>megawatthours</td></tr><tr><td>2015-07-01T20</td><td>CISO</td><td>California Independent System Operator</td><td>D< ...

# %%
display(dbutils.fs.mounts())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mountPoint</th><th>source</th><th>encryptionType</th></tr></thead><tbody><tr><td>/mnt/jesse-ramen</td><td>abfss://ramen@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/jeremygarrison</td><td>abfss://jeremygarrison@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/jess-cell</td><td>abfss://celltowers@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/jinheelee-ramen</td><td>abfss://ramen@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/nick-detroit</td><td>abfss://detroit911@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/shanesarabdial-</td><td>abfss://shanesarabdial@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/edward-detroit</td><td>abfss://detroit911@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/mattcizek</td><td>abfss://mattcizek@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/noellekiesz</td><td>abfss://noellekiesz@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/jesse-pokemon</td><td>abfss://jessenoss@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/miko-detroit</td><td>abfss://detroit911@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/shane-cell</td><td>abfss://celltowers@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/databricks-datasets</td><td>databricks-datasets</td><td></td></tr><tr><td>/mnt/vanessa-detroit</td><td>abfss://detroit911@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/beth-cell</td><td>abfss://celltowers@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/vanessa-cell</td><td>abfss://celltowers@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/vanessaschroeder</td><td>abfss://vschroeder@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/heatherrobbins</td><td>abfss://heatherrobbins@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/sam-celltowers</td><td>abfss://celltowers@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/shanesarabdial/data</td><td>abfss://shanesarabdial@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/sam-cell</td><td>abfss://celltowers@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/shanesarabdial</td><td>abfss://shanesarabdial@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/sammoe</td><td>abfss://sammoe@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/cell-jesshoffman</td><td>abfss://cell-jesshoffman@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/adi-detroit</td><td>abfss://adityapalapati@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/jake-celltowers</td><td>abfss://celltowers@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/becca-cell</td><td>abfss://celltowers@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/beth-ramen</td><td>abfss://ramen@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/tristen-celltower</td><td>abfss://tristen-celltower@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/cell-vschroeder</td><td>abfss://cell-vschroeder@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/matt-ramen</td><td>abfss://ramen@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/heather-squirrels</td><td>abfss://squirrels@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/nicholasfenech</td><td>abfss://nicholasfenech@cohort50storage.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/tristen-celltowers</td><td>abfss://celltowers@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/jesse-detroit</td><td>abfss://detroit911@c50datafiles.dfs.core.windows.net/</td><td></td></tr><tr><td>/mnt/shirleycho</td><td>abfss ...

# %%
df = df.repartition(1)
df.write.mode("overwrite").parquet('/mnt/weatherwatts/EIApartition')
